# %% [markdown]
# # ECOfull Implementation

# %% [markdown]
# ### References :
#
# <li>BNInception: https://github.com/Cadene/pretrained-models.pytorch/blob/master/pretrainedmodels/models/bninception.py</li>
# <li>ECO-PyTorch : https://github.com/mzolfaghari/ECO-pytorch</li>
# <li>ECO-Lite Implementation : https://github.com/YutaroOgawa/pytorch_advanced/tree/master/9_video_classification_eco</li>

# %%
import os
import torch
import torch.nn as nn
from torch.nn import init

# %%
weights_dir = "./weights/"
if not os.path.exists(weights_dir):
    os.mkdir(weights_dir)

# %% [markdown]
# # Dataloader for Kinematics

# %%
from utils.kinetics400_eco_dataloader import make_datapath_list, VideoTransform, get_label_id_dictionary, VideoDataset

root_path = './data/kinetics_videos/'
video_list = make_datapath_list(root_path)

resize, crop_size = 224, 224
mean, std = [104, 117, 123], [1, 1, 1]
video_transform = VideoTransform(resize, crop_size, mean, std)

label_dicitionary_path = 'kinetics_400_label_dicitionary.csv'
label_id_dict, id_label_dict = get_label_id_dictionary(label_dicitionary_path)


val_dataset = VideoDataset(video_list, label_id_dict, num_segments=16,
                           phase="val", transform=video_transform, img_tmpl='image_{:05d}.jpg')

batch_size = 8
val_dataloader = torch.utils.data.DataLoader(
    val_dataset, batch_size=batch_size, shuffle=False)


batch_iterator = iter(val_dataloader)  
imgs_transformeds, labels, label_ids, dir_path = next(
    batch_iterator)  
print(imgs_transformeds.shape)
# Out:
# torch.Size([8, 16, 3, 224, 224])

# %% [markdown]
# # Import ECOfull

# %%
from utils.ecofull import ECOfull

# %%
net = ECOfull()
net
# Out:
# ECOfull(
#   (conv1_7x7_s2): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#   (conv1_7x7_s2_bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv1_relu_7x7): ReLU(inplace)
#   (pool1_3x3_s2): MaxPool2d(kernel_size=(3, 3), stride=(2, 2), padding=0, dilation=(1, 1), ceil_mode=True)
#   (conv2_3x3_reduce): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#   (conv2_3x3_reduce_bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv2_relu_3x3_reduce): ReLU(inplace)
#   (conv2_3x3): Conv2d(64, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv2_3x3_bn): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv2_relu_3x3): ReLU(inplace)
#   (pool2_3x3_s2): MaxPool2d(kernel_size=(3, 3), stride=(2, 2), padding=0, dilation=(1, 1), ceil_mode=True)
#   (inception_3a_1x1): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1))
#   (inception_3a_1x1_bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (inception_3a_relu_1x1): ReLU(inplace)
#   (inception_3a_3x3_reduce): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1))
#   (inception_3a_3x3_reduce_bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (inception_3a_relu_3x3_reduce): ReLU(inplace)
#   (inception_3a_3x3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (inception_3a_3x3_bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (inception_3a_relu_3x3): ReLU(inplace)
#   (inception_3a_double_3x3_reduce): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1))
#   (inception_3a_double_3x3_reduce_bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (inception_3a_relu_double_3x3_reduce): ReLU(inplace)
#   (inception_3a_double_3x3_1): Conv2d(64, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (inception_3a_double_3x3_1_bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (inception_3a_relu_double_3x3_1): ReLU(inplace)
#   (inception_3a_double_3x3_2): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (inception_3a_double_3x3_2_bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (inception_3a_relu_double_3x3_2): ReLU(inplace)
#   (inception_3a_pool): AvgPool2d(kernel_size=3, stride=1, padding=1)
#   (inception_3a_pool_proj): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1))
#   (inception_3a_pool_proj_bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (inception_3a_relu_pool_proj): ReLU(inplace)
#   (inception_3b_1x1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1))
#   (inception_3b_1x1_bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (inception_3b_relu_1x1): ReLU(inplace)
#   (inception_3b_3x3_reduce): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1))
#   (inception_3b_3x3_reduce_bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (inception_3b_relu_3x3_reduce): ReLU(inplace)
#   (inception_3b_3x3): Conv2d(64, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (inception_3b_3x3_bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (inception_3b_relu_3x3): ReLU(inplace)
#   (inception_3b_double_3x3_reduce): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1))
#   (inception_3b_double_3x3_reduce_bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (inception_3b_relu_double_3x3_reduce): ReLU(inplace)
#   (inception_3b_double_3x3_1): Conv2d(64, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (inception_3b_double_3x3_1_bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (inception_3b_relu_double_3x3_1): ReLU(inplace)
#   (inception_3b_double_3x3_2): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (inception_3b_double_3x3_2_bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (inception_3b_relu_double_3x3_2): ReLU(inplace)
#   (inception_3b_pool): AvgPool2d(kernel_size=3, stride=1, padding=1)
#   (inception_3b_pool_proj): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1))
#   (inception_3b_pool_proj_bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (inception_3b_relu_pool_proj): ReLU(inplace)
#   (inception_3c_3x3_reduce): Conv2d(320, 128, kernel_size=(1, 1), stride=(1, 1))
#   (inception_3c_3x3_reduce_bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (inception_3c_relu_3x3_reduce): ReLU(inplace)
#   (inception_3c_3x3): Conv2d(128, 160, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#   (inception_3c_3x3_bn): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (inception_3c_relu_3x3): ReLU(inplace)
#   (inception_3c_double_3x3_reduce): Conv2d(320, 64, kernel_size=(1, 1), stride=(1, 1))
#   (inception_3c_double_3x3_reduce_bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (inception_3c_relu_double_3x3_reduce): ReLU(inplace)
#   (inception_3c_double_3x3_1): Conv2d(64, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (inception_3c_double_3x3_1_bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (inception_3c_relu_double_3x3_1): ReLU(inplace)
#   (res3a_2): Conv3d(96, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#   (res3a_bn): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (res3a_relu): ReLU(inplace)
#   (res3b_1): Conv3d(128, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#   (res3b_1_bn): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (res3b_1_relu): ReLU(inplace)
#   (res3b_2): Conv3d(128, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#   (res3b_bn): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (res3b_relu): ReLU(inplace)
#   (res4a_1): Conv3d(128, 256, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1))
#   (res4a_1_bn): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (res4a_1_relu): ReLU(inplace)
#   (res4a_2): Conv3d(256, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#   (res4a_down): Conv3d(128, 256, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1))
#   (res4a_bn): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (res4a_relu): ReLU(inplace)
#   (res4b_1): Conv3d(256, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#   (res4b_1_bn): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (res4b_1_relu): ReLU(inplace)
#   (res4b_2): Conv3d(256, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#   (res4b_bn): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (res4b_relu): ReLU(inplace)
#   (res5a_1): Conv3d(256, 512, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1))
#   (res5a_1_bn): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (res5a_1_relu): ReLU(inplace)
#   (res5a_2): Conv3d(512, 512, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#   (res5a_down): Conv3d(256, 512, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1))
#   (res5a_bn): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (res5a_relu): ReLU(inplace)
#   (res5b_1): Conv3d(512, 512, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#   (res5b_1_bn): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (res5b_1_relu): ReLU(inplace)
#   (res5b_2): Conv3d(512, 512, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#   (res5b_bn): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (res5b_relu): ReLU(inplace)
#   (inception_3c_double_3x3_2): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#   (inception_3c_double_3x3_2_bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (inception_3c_relu_double_3x3_2): ReLU(inplace)
#   (inception_3c_pool): MaxPool2d(kernel_size=(3, 3), stride=(2, 2), padding=0, dilation=(1, 1), ceil_mode=True)
#   (inception_4a_1x1): Conv2d(576, 224, kernel_size=(1, 1), stride=(1, 1))
#   (inception_4a_1x1_bn): BatchNorm2d(224, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (inception_4a_relu_1x1): ReLU(inplace)
#   (inception_4a_3x3_reduce): Conv2d(576, 64, kernel_size=(1, 1), stride=(1, 1))
#   (inception_4a_3x3_reduce_bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (inception_4a_relu_3x3_reduce): ReLU(inplace)
#   (inception_4a_3x3): Conv2d(64, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (inception_4a_3x3_bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (inception_4a_relu_3x3): ReLU(inplace)
#   (inception_4a_double_3x3_reduce): Conv2d(576, 96, kernel_size=(1, 1), stride=(1, 1))
#   (inception_4a_double_3x3_reduce_bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (inception_4a_relu_double_3x3_reduce): ReLU(inplace)
#   (inception_4a_double_3x3_1): Conv2d(96, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (inception_4a_double_3x3_1_bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (inception_4a_relu_double_3x3_1): ReLU(inplace)
#   (inception_4a_double_3x3_2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (inception_4a_double_3x3_2_bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (inception_4a_relu_double_3x3_2): ReLU(inplace)
#   (inception_4a_pool): AvgPool2d(kernel_size=3, stride=1, padding=1)
#   (inception_4a_pool_proj): Conv2d(576, 128, kernel_size=(1, 1), stride=(1, 1))
#   (inception_4a_pool_proj_bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (inception_4a_relu_pool_proj): ReLU(inplace)
#   (inception_4b_1x1): Conv2d(576, 192, kernel_size=(1, 1), stride=(1, 1))
#   (inception_4b_1x1_bn): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (inception_4b_relu_1x1): ReLU(inplace)
#   (inception_4b_3x3_reduce): Conv2d(576, 96, kernel_size=(1, 1), stride=(1, 1))
#   (inception_4b_3x3_reduce_bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (inception_4b_relu_3x3_reduce): ReLU(inplace)
#   (inception_4b_3x3): Conv2d(96, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (inception_4b_3x3_bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (inception_4b_relu_3x3): ReLU(inplace)
#   (inception_4b_double_3x3_reduce): Conv2d(576, 96, kernel_size=(1, 1), stride=(1, 1))
#   (inception_4b_double_3x3_reduce_bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (inception_4b_relu_double_3x3_reduce): ReLU(inplace)
#   (inception_4b_double_3x3_1): Conv2d(96, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (inception_4b_double_3x3_1_bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (inception_4b_relu_double_3x3_1): ReLU(inplace)
#   (inception_4b_double_3x3_2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (inception_4b_double_3x3_2_bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (inception_4b_relu_double_3x3_2): ReLU(inplace)
#   (inception_4b_pool): AvgPool2d(kernel_size=3, stride=1, padding=1)
#   (inception_4b_pool_proj): Conv2d(576, 128, kernel_size=(1, 1), stride=(1, 1))
#   (inception_4b_pool_proj_bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (inception_4b_relu_pool_proj): ReLU(inplace)
#   (inception_4c_1x1): Conv2d(576, 160, kernel_size=(1, 1), stride=(1, 1))
#   (inception_4c_1x1_bn): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (inception_4c_relu_1x1): ReLU(inplace)
#   (inception_4c_3x3_reduce): Conv2d(576, 128, kernel_size=(1, 1), stride=(1, 1))
#   (inception_4c_3x3_reduce_bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (inception_4c_relu_3x3_reduce): ReLU(inplace)
#   (inception_4c_3x3): Conv2d(128, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (inception_4c_3x3_bn): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (inception_4c_relu_3x3): ReLU(inplace)
#   (inception_4c_double_3x3_reduce): Conv2d(576, 128, kernel_size=(1, 1), stride=(1, 1))
#   (inception_4c_double_3x3_reduce_bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (inception_4c_relu_double_3x3_reduce): ReLU(inplace)
#   (inception_4c_double_3x3_1): Conv2d(128, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (inception_4c_double_3x3_1_bn): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (inception_4c_relu_double_3x3_1): ReLU(inplace)
#   (inception_4c_double_3x3_2): Conv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (inception_4c_double_3x3_2_bn): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (inception_4c_relu_double_3x3_2): ReLU(inplace)
#   (inception_4c_pool): AvgPool2d(kernel_size=3, stride=1, padding=1)
#   (inception_4c_pool_proj): Conv2d(576, 128, kernel_size=(1, 1), stride=(1, 1))
#   (inception_4c_pool_proj_bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (inception_4c_relu_pool_proj): ReLU(inplace)
#   (inception_4d_1x1): Conv2d(608, 96, kernel_size=(1, 1), stride=(1, 1))
#   (inception_4d_1x1_bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (inception_4d_relu_1x1): ReLU(inplace)
#   (inception_4d_3x3_reduce): Conv2d(608, 128, kernel_size=(1, 1), stride=(1, 1))
#   (inception_4d_3x3_reduce_bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (inception_4d_relu_3x3_reduce): ReLU(inplace)
#   (inception_4d_3x3): Conv2d(128, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (inception_4d_3x3_bn): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (inception_4d_relu_3x3): ReLU(inplace)
#   (inception_4d_double_3x3_reduce): Conv2d(608, 160, kernel_size=(1, 1), stride=(1, 1))
#   (inception_4d_double_3x3_reduce_bn): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (inception_4d_relu_double_3x3_reduce): ReLU(inplace)
#   (inception_4d_double_3x3_1): Conv2d(160, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (inception_4d_double_3x3_1_bn): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (inception_4d_relu_double_3x3_1): ReLU(inplace)
#   (inception_4d_double_3x3_2): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (inception_4d_double_3x3_2_bn): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (inception_4d_relu_double_3x3_2): ReLU(inplace)
#   (inception_4d_pool): AvgPool2d(kernel_size=3, stride=1, padding=1)
#   (inception_4d_pool_proj): Conv2d(608, 128, kernel_size=(1, 1), stride=(1, 1))
#   (inception_4d_pool_proj_bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (inception_4d_relu_pool_proj): ReLU(inplace)
#   (inception_4e_3x3_reduce): Conv2d(608, 128, kernel_size=(1, 1), stride=(1, 1))
#   (inception_4e_3x3_reduce_bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (inception_4e_relu_3x3_reduce): ReLU(inplace)
#   (inception_4e_3x3): Conv2d(128, 192, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#   (inception_4e_3x3_bn): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (inception_4e_relu_3x3): ReLU(inplace)
#   (inception_4e_double_3x3_reduce): Conv2d(608, 192, kernel_size=(1, 1), stride=(1, 1))
#   (inception_4e_double_3x3_reduce_bn): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (inception_4e_relu_double_3x3_reduce): ReLU(inplace)
#   (inception_4e_double_3x3_1): Conv2d(192, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (inception_4e_double_3x3_1_bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (inception_4e_relu_double_3x3_1): ReLU(inplace)
#   (inception_4e_double_3x3_2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#   (inception_4e_double_3x3_2_bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (inception_4e_relu_double_3x3_2): ReLU(inplace)
#   (inception_4e_pool): MaxPool2d(kernel_size=(3, 3), stride=(2, 2), padding=0, dilation=(1, 1), ceil_mode=True)
#   (inception_5a_1x1): Conv2d(1056, 352, kernel_size=(1, 1), stride=(1, 1))
#   (inception_5a_1x1_bn): BatchNorm2d(352, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (inception_5a_relu_1x1): ReLU(inplace)
#   (inception_5a_3x3_reduce): Conv2d(1056, 192, kernel_size=(1, 1), stride=(1, 1))
#   (inception_5a_3x3_reduce_bn): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (inception_5a_relu_3x3_reduce): ReLU(inplace)
#   (inception_5a_3x3): Conv2d(192, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (inception_5a_3x3_bn): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (inception_5a_relu_3x3): ReLU(inplace)
#   (inception_5a_double_3x3_reduce): Conv2d(1056, 160, kernel_size=(1, 1), stride=(1, 1))
#   (inception_5a_double_3x3_reduce_bn): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (inception_5a_relu_double_3x3_reduce): ReLU(inplace)
#   (inception_5a_double_3x3_1): Conv2d(160, 224, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (inception_5a_double_3x3_1_bn): BatchNorm2d(224, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (inception_5a_relu_double_3x3_1): ReLU(inplace)
#   (inception_5a_double_3x3_2): Conv2d(224, 224, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (inception_5a_double_3x3_2_bn): BatchNorm2d(224, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (inception_5a_relu_double_3x3_2): ReLU(inplace)
#   (inception_5a_pool): AvgPool2d(kernel_size=3, stride=1, padding=1)
#   (inception_5a_pool_proj): Conv2d(1056, 128, kernel_size=(1, 1), stride=(1, 1))
#   (inception_5a_pool_proj_bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (inception_5a_relu_pool_proj): ReLU(inplace)
#   (inception_5b_1x1): Conv2d(1024, 352, kernel_size=(1, 1), stride=(1, 1))
#   (inception_5b_1x1_bn): BatchNorm2d(352, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (inception_5b_relu_1x1): ReLU(inplace)
#   (inception_5b_3x3_reduce): Conv2d(1024, 192, kernel_size=(1, 1), stride=(1, 1))
#   (inception_5b_3x3_reduce_bn): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (inception_5b_relu_3x3_reduce): ReLU(inplace)
#   (inception_5b_3x3): Conv2d(192, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (inception_5b_3x3_bn): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (inception_5b_relu_3x3): ReLU(inplace)
#   (inception_5b_double_3x3_reduce): Conv2d(1024, 192, kernel_size=(1, 1), stride=(1, 1))
#   (inception_5b_double_3x3_reduce_bn): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (inception_5b_relu_double_3x3_reduce): ReLU(inplace)
#   (inception_5b_double_3x3_1): Conv2d(192, 224, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (inception_5b_double_3x3_1_bn): BatchNorm2d(224, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (inception_5b_relu_double_3x3_1): ReLU(inplace)
#   (inception_5b_double_3x3_2): Conv2d(224, 224, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (inception_5b_double_3x3_2_bn): BatchNorm2d(224, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (inception_5b_relu_double_3x3_2): ReLU(inplace)
#   (inception_5b_pool): MaxPool2d(kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), dilation=(1, 1), ceil_mode=True)
#   (inception_5b_pool_proj): Conv2d(1024, 128, kernel_size=(1, 1), stride=(1, 1))
#   (inception_5b_pool_proj_bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (inception_5b_relu_pool_proj): ReLU(inplace)
#   (global_pool2D_pre): AvgPool2d(kernel_size=7, stride=1, padding=0)
#   (global_pool2D_pre_drop): Dropout(p=0.5)
#   (global_pool2D_reshape_consensus): AvgPool3d(kernel_size=(16, 1, 1), stride=1, padding=0)
#   (global_pool3D): AvgPool3d(kernel_size=(4, 7, 7), stride=1, padding=0)
#   (global_pool3D_drop): Dropout(p=0.3)
#   (fc_final): Linear(in_features=1536, out_features=400, bias=True)
# )

# %% [markdown]
# # Load Pre-Train Model

# %%
def load_pretrained_ECO(model_dict, pretrained_model_dict):

    param_names = [] 
    for name, param in model_dict.items():
        param_names.append(name)

    new_state_dict = model_dict.copy()

    print("Load learned parameters")
    for index, (key_name, value) in enumerate(pretrained_model_dict.items()):
        name = param_names[index]  
        new_state_dict[name] = value  

        print(str(key_name)+"→"+str(name))

    return new_state_dict

# %%
net_model_ECO = "./weights/ECO_Full_rgb_model_Kinetics.pth.tar"
pretrained_model = torch.load(net_model_ECO, map_location='cpu')
pretrained_model_dict = pretrained_model['state_dict']

model_dict = net.state_dict()
new_state_dict = load_pretrained_ECO(model_dict, pretrained_model_dict)

net.eval()  
net.load_state_dict(new_state_dict)
# Out:
# Load learned parameters
# module.base_model.conv1_7x7_s2.weight→conv1_7x7_s2.weight
# module.base_model.conv1_7x7_s2.bias→conv1_7x7_s2.bias
# module.base_model.conv1_7x7_s2_bn.weight→conv1_7x7_s2_bn.weight
# module.base_model.conv1_7x7_s2_bn.bias→conv1_7x7_s2_bn.bias
# module.base_model.conv1_7x7_s2_bn.running_mean→conv1_7x7_s2_bn.running_mean
# module.base_model.conv1_7x7_s2_bn.running_var→conv1_7x7_s2_bn.running_var
# module.base_model.conv1_7x7_s2_bn.num_batches_tracked→conv1_7x7_s2_bn.num_batches_tracked
# module.base_model.conv2_3x3_reduce.weight→conv2_3x3_reduce.weight
# module.base_model.conv2_3x3_reduce.bias→conv2_3x3_reduce.bias
# module.base_model.conv2_3x3_reduce_bn.weight→conv2_3x3_reduce_bn.weight
# module.base_model.conv2_3x3_reduce_bn.bias→conv2_3x3_reduce_bn.bias
# module.base_model.conv2_3x3_reduce_bn.running_mean→conv2_3x3_reduce_bn.running_mean
# module.base_model.conv2_3x3_reduce_bn.running_var→conv2_3x3_reduce_bn.running_var
# module.base_model.conv2_3x3_reduce_bn.num_batches_tracked→conv2_3x3_reduce_bn.num_batches_tracked
# module.base_model.conv2_3x3.weight→conv2_3x3.weight
# module.base_model.conv2_3x3.bias→conv2_3x3.bias
# module.base_model.conv2_3x3_bn.weight→conv2_3x3_bn.weight
# module.base_model.conv2_3x3_bn.bias→conv2_3x3_bn.bias
# module.base_model.conv2_3x3_bn.running_mean→conv2_3x3_bn.running_mean
# module.base_model.conv2_3x3_bn.running_var→conv2_3x3_bn.running_var
# module.base_model.conv2_3x3_bn.num_batches_tracked→conv2_3x3_bn.num_batches_tracked
# module.base_model.inception_3a_1x1.weight→inception_3a_1x1.weight
# module.base_model.inception_3a_1x1.bias→inception_3a_1x1.bias
# module.base_model.inception_3a_1x1_bn.weight→inception_3a_1x1_bn.weight
# module.base_model.inception_3a_1x1_bn.bias→inception_3a_1x1_bn.bias
# module.base_model.inception_3a_1x1_bn.running_mean→inception_3a_1x1_bn.running_mean
# module.base_model.inception_3a_1x1_bn.running_var→inception_3a_1x1_bn.running_var
# module.base_model.inception_3a_1x1_bn.num_batches_tracked→inception_3a_1x1_bn.num_batches_tracked
# module.base_model.inception_3a_3x3_reduce.weight→inception_3a_3x3_reduce.weight
# module.base_model.inception_3a_3x3_reduce.bias→inception_3a_3x3_reduce.bias
# module.base_model.inception_3a_3x3_reduce_bn.weight→inception_3a_3x3_reduce_bn.weight
# module.base_model.inception_3a_3x3_reduce_bn.bias→inception_3a_3x3_reduce_bn.bias
# module.base_model.inception_3a_3x3_reduce_bn.running_mean→inception_3a_3x3_reduce_bn.running_mean
# module.base_model.inception_3a_3x3_reduce_bn.running_var→inception_3a_3x3_reduce_bn.running_var
# module.base_model.inception_3a_3x3_reduce_bn.num_batches_tracked→inception_3a_3x3_reduce_bn.num_batches_tracked
# module.base_model.inception_3a_3x3.weight→inception_3a_3x3.weight
# module.base_model.inception_3a_3x3.bias→inception_3a_3x3.bias
# module.base_model.inception_3a_3x3_bn.weight→inception_3a_3x3_bn.weight
# module.base_model.inception_3a_3x3_bn.bias→inception_3a_3x3_bn.bias
# module.base_model.inception_3a_3x3_bn.running_mean→inception_3a_3x3_bn.running_mean
# module.base_model.inception_3a_3x3_bn.running_var→inception_3a_3x3_bn.running_var
# module.base_model.inception_3a_3x3_bn.num_batches_tracked→inception_3a_3x3_bn.num_batches_tracked
# module.base_model.inception_3a_double_3x3_reduce.weight→inception_3a_double_3x3_reduce.weight
# module.base_model.inception_3a_double_3x3_reduce.bias→inception_3a_double_3x3_reduce.bias
# module.base_model.inception_3a_double_3x3_reduce_bn.weight→inception_3a_double_3x3_reduce_bn.weight
# module.base_model.inception_3a_double_3x3_reduce_bn.bias→inception_3a_double_3x3_reduce_bn.bias
# module.base_model.inception_3a_double_3x3_reduce_bn.running_mean→inception_3a_double_3x3_reduce_bn.running_mean
# module.base_model.inception_3a_double_3x3_reduce_bn.running_var→inception_3a_double_3x3_reduce_bn.running_var
# module.base_model.inception_3a_double_3x3_reduce_bn.num_batches_tracked→inception_3a_double_3x3_reduce_bn.num_batches_tracked
# module.base_model.inception_3a_double_3x3_1.weight→inception_3a_double_3x3_1.weight
# module.base_model.inception_3a_double_3x3_1.bias→inception_3a_double_3x3_1.bias
# module.base_model.inception_3a_double_3x3_1_bn.weight→inception_3a_double_3x3_1_bn.weight
# module.base_model.inception_3a_double_3x3_1_bn.bias→inception_3a_double_3x3_1_bn.bias
# module.base_model.inception_3a_double_3x3_1_bn.running_mean→inception_3a_double_3x3_1_bn.running_mean
# module.base_model.inception_3a_double_3x3_1_bn.running_var→inception_3a_double_3x3_1_bn.running_var
# module.base_model.inception_3a_double_3x3_1_bn.num_batches_tracked→inception_3a_double_3x3_1_bn.num_batches_tracked
# module.base_model.inception_3a_double_3x3_2.weight→inception_3a_double_3x3_2.weight
# module.base_model.inception_3a_double_3x3_2.bias→inception_3a_double_3x3_2.bias
# module.base_model.inception_3a_double_3x3_2_bn.weight→inception_3a_double_3x3_2_bn.weight
# module.base_model.inception_3a_double_3x3_2_bn.bias→inception_3a_double_3x3_2_bn.bias
# module.base_model.inception_3a_double_3x3_2_bn.running_mean→inception_3a_double_3x3_2_bn.running_mean
# module.base_model.inception_3a_double_3x3_2_bn.running_var→inception_3a_double_3x3_2_bn.running_var
# module.base_model.inception_3a_double_3x3_2_bn.num_batches_tracked→inception_3a_double_3x3_2_bn.num_batches_tracked
# module.base_model.inception_3a_pool_proj.weight→inception_3a_pool_proj.weight
# module.base_model.inception_3a_pool_proj.bias→inception_3a_pool_proj.bias
# module.base_model.inception_3a_pool_proj_bn.weight→inception_3a_pool_proj_bn.weight
# module.base_model.inception_3a_pool_proj_bn.bias→inception_3a_pool_proj_bn.bias
# module.base_model.inception_3a_pool_proj_bn.running_mean→inception_3a_pool_proj_bn.running_mean
# module.base_model.inception_3a_pool_proj_bn.running_var→inception_3a_pool_proj_bn.running_var
# module.base_model.inception_3a_pool_proj_bn.num_batches_tracked→inception_3a_pool_proj_bn.num_batches_tracked
# module.base_model.inception_3b_1x1.weight→inception_3b_1x1.weight
# module.base_model.inception_3b_1x1.bias→inception_3b_1x1.bias
# module.base_model.inception_3b_1x1_bn.weight→inception_3b_1x1_bn.weight
# module.base_model.inception_3b_1x1_bn.bias→inception_3b_1x1_bn.bias
# module.base_model.inception_3b_1x1_bn.running_mean→inception_3b_1x1_bn.running_mean
# module.base_model.inception_3b_1x1_bn.running_var→inception_3b_1x1_bn.running_var
# module.base_model.inception_3b_1x1_bn.num_batches_tracked→inception_3b_1x1_bn.num_batches_tracked
# module.base_model.inception_3b_3x3_reduce.weight→inception_3b_3x3_reduce.weight
# module.base_model.inception_3b_3x3_reduce.bias→inception_3b_3x3_reduce.bias
# module.base_model.inception_3b_3x3_reduce_bn.weight→inception_3b_3x3_reduce_bn.weight
# module.base_model.inception_3b_3x3_reduce_bn.bias→inception_3b_3x3_reduce_bn.bias
# module.base_model.inception_3b_3x3_reduce_bn.running_mean→inception_3b_3x3_reduce_bn.running_mean
# module.base_model.inception_3b_3x3_reduce_bn.running_var→inception_3b_3x3_reduce_bn.running_var
# module.base_model.inception_3b_3x3_reduce_bn.num_batches_tracked→inception_3b_3x3_reduce_bn.num_batches_tracked
# module.base_model.inception_3b_3x3.weight→inception_3b_3x3.weight
# module.base_model.inception_3b_3x3.bias→inception_3b_3x3.bias
# module.base_model.inception_3b_3x3_bn.weight→inception_3b_3x3_bn.weight
# module.base_model.inception_3b_3x3_bn.bias→inception_3b_3x3_bn.bias
# module.base_model.inception_3b_3x3_bn.running_mean→inception_3b_3x3_bn.running_mean
# module.base_model.inception_3b_3x3_bn.running_var→inception_3b_3x3_bn.running_var
# module.base_model.inception_3b_3x3_bn.num_batches_tracked→inception_3b_3x3_bn.num_batches_tracked
# module.base_model.inception_3b_double_3x3_reduce.weight→inception_3b_double_3x3_reduce.weight
# module.base_model.inception_3b_double_3x3_reduce.bias→inception_3b_double_3x3_reduce.bias
# module.base_model.inception_3b_double_3x3_reduce_bn.weight→inception_3b_double_3x3_reduce_bn.weight
# module.base_model.inception_3b_double_3x3_reduce_bn.bias→inception_3b_double_3x3_reduce_bn.bias
# module.base_model.inception_3b_double_3x3_reduce_bn.running_mean→inception_3b_double_3x3_reduce_bn.running_mean
# module.base_model.inception_3b_double_3x3_reduce_bn.running_var→inception_3b_double_3x3_reduce_bn.running_var
# module.base_model.inception_3b_double_3x3_reduce_bn.num_batches_tracked→inception_3b_double_3x3_reduce_bn.num_batches_tracked
# module.base_model.inception_3b_double_3x3_1.weight→inception_3b_double_3x3_1.weight
# module.base_model.inception_3b_double_3x3_1.bias→inception_3b_double_3x3_1.bias
# module.base_model.inception_3b_double_3x3_1_bn.weight→inception_3b_double_3x3_1_bn.weight
# module.base_model.inception_3b_double_3x3_1_bn.bias→inception_3b_double_3x3_1_bn.bias
# module.base_model.inception_3b_double_3x3_1_bn.running_mean→inception_3b_double_3x3_1_bn.running_mean
# module.base_model.inception_3b_double_3x3_1_bn.running_var→inception_3b_double_3x3_1_bn.running_var
# module.base_model.inception_3b_double_3x3_1_bn.num_batches_tracked→inception_3b_double_3x3_1_bn.num_batches_tracked
# module.base_model.inception_3b_double_3x3_2.weight→inception_3b_double_3x3_2.weight
# module.base_model.inception_3b_double_3x3_2.bias→inception_3b_double_3x3_2.bias
# module.base_model.inception_3b_double_3x3_2_bn.weight→inception_3b_double_3x3_2_bn.weight
# module.base_model.inception_3b_double_3x3_2_bn.bias→inception_3b_double_3x3_2_bn.bias
# module.base_model.inception_3b_double_3x3_2_bn.running_mean→inception_3b_double_3x3_2_bn.running_mean
# module.base_model.inception_3b_double_3x3_2_bn.running_var→inception_3b_double_3x3_2_bn.running_var
# module.base_model.inception_3b_double_3x3_2_bn.num_batches_tracked→inception_3b_double_3x3_2_bn.num_batches_tracked
# module.base_model.inception_3b_pool_proj.weight→inception_3b_pool_proj.weight
# module.base_model.inception_3b_pool_proj.bias→inception_3b_pool_proj.bias
# module.base_model.inception_3b_pool_proj_bn.weight→inception_3b_pool_proj_bn.weight
# module.base_model.inception_3b_pool_proj_bn.bias→inception_3b_pool_proj_bn.bias
# module.base_model.inception_3b_pool_proj_bn.running_mean→inception_3b_pool_proj_bn.running_mean
# module.base_model.inception_3b_pool_proj_bn.running_var→inception_3b_pool_proj_bn.running_var
# module.base_model.inception_3b_pool_proj_bn.num_batches_tracked→inception_3b_pool_proj_bn.num_batches_tracked
# module.base_model.inception_3c_3x3_reduce.weight→inception_3c_3x3_reduce.weight
# module.base_model.inception_3c_3x3_reduce.bias→inception_3c_3x3_reduce.bias
# module.base_model.inception_3c_3x3_reduce_bn.weight→inception_3c_3x3_reduce_bn.weight
# module.base_model.inception_3c_3x3_reduce_bn.bias→inception_3c_3x3_reduce_bn.bias
# module.base_model.inception_3c_3x3_reduce_bn.running_mean→inception_3c_3x3_reduce_bn.running_mean
# module.base_model.inception_3c_3x3_reduce_bn.running_var→inception_3c_3x3_reduce_bn.running_var
# module.base_model.inception_3c_3x3_reduce_bn.num_batches_tracked→inception_3c_3x3_reduce_bn.num_batches_tracked
# module.base_model.inception_3c_3x3.weight→inception_3c_3x3.weight
# module.base_model.inception_3c_3x3.bias→inception_3c_3x3.bias
# module.base_model.inception_3c_3x3_bn.weight→inception_3c_3x3_bn.weight
# module.base_model.inception_3c_3x3_bn.bias→inception_3c_3x3_bn.bias
# module.base_model.inception_3c_3x3_bn.running_mean→inception_3c_3x3_bn.running_mean
# module.base_model.inception_3c_3x3_bn.running_var→inception_3c_3x3_bn.running_var
# module.base_model.inception_3c_3x3_bn.num_batches_tracked→inception_3c_3x3_bn.num_batches_tracked
# module.base_model.inception_3c_double_3x3_reduce.weight→inception_3c_double_3x3_reduce.weight
# module.base_model.inception_3c_double_3x3_reduce.bias→inception_3c_double_3x3_reduce.bias
# module.base_model.inception_3c_double_3x3_reduce_bn.weight→inception_3c_double_3x3_reduce_bn.weight
# module.base_model.inception_3c_double_3x3_reduce_bn.bias→inception_3c_double_3x3_reduce_bn.bias
# module.base_model.inception_3c_double_3x3_reduce_bn.running_mean→inception_3c_double_3x3_reduce_bn.running_mean
# module.base_model.inception_3c_double_3x3_reduce_bn.running_var→inception_3c_double_3x3_reduce_bn.running_var
# module.base_model.inception_3c_double_3x3_reduce_bn.num_batches_tracked→inception_3c_double_3x3_reduce_bn.num_batches_tracked
# module.base_model.inception_3c_double_3x3_1.weight→inception_3c_double_3x3_1.weight
# module.base_model.inception_3c_double_3x3_1.bias→inception_3c_double_3x3_1.bias
# module.base_model.inception_3c_double_3x3_1_bn.weight→inception_3c_double_3x3_1_bn.weight
# module.base_model.inception_3c_double_3x3_1_bn.bias→inception_3c_double_3x3_1_bn.bias
# module.base_model.inception_3c_double_3x3_1_bn.running_mean→inception_3c_double_3x3_1_bn.running_mean
# module.base_model.inception_3c_double_3x3_1_bn.running_var→inception_3c_double_3x3_1_bn.running_var
# module.base_model.inception_3c_double_3x3_1_bn.num_batches_tracked→inception_3c_double_3x3_1_bn.num_batches_tracked
# module.base_model.res3a_2.weight→res3a_2.weight
# module.base_model.res3a_2.bias→res3a_2.bias
# module.base_model.res3a_bn.weight→res3a_bn.weight
# module.base_model.res3a_bn.bias→res3a_bn.bias
# module.base_model.res3a_bn.running_mean→res3a_bn.running_mean
# module.base_model.res3a_bn.running_var→res3a_bn.running_var
# module.base_model.res3a_bn.num_batches_tracked→res3a_bn.num_batches_tracked
# module.base_model.res3b_1.weight→res3b_1.weight
# module.base_model.res3b_1.bias→res3b_1.bias
# module.base_model.res3b_1_bn.weight→res3b_1_bn.weight
# module.base_model.res3b_1_bn.bias→res3b_1_bn.bias
# module.base_model.res3b_1_bn.running_mean→res3b_1_bn.running_mean
# module.base_model.res3b_1_bn.running_var→res3b_1_bn.running_var
# module.base_model.res3b_1_bn.num_batches_tracked→res3b_1_bn.num_batches_tracked
# module.base_model.res3b_2.weight→res3b_2.weight
# module.base_model.res3b_2.bias→res3b_2.bias
# module.base_model.res3b_bn.weight→res3b_bn.weight
# module.base_model.res3b_bn.bias→res3b_bn.bias
# module.base_model.res3b_bn.running_mean→res3b_bn.running_mean
# module.base_model.res3b_bn.running_var→res3b_bn.running_var
# module.base_model.res3b_bn.num_batches_tracked→res3b_bn.num_batches_tracked
# module.base_model.res4a_1.weight→res4a_1.weight
# module.base_model.res4a_1.bias→res4a_1.bias
# module.base_model.res4a_1_bn.weight→res4a_1_bn.weight
# module.base_model.res4a_1_bn.bias→res4a_1_bn.bias
# module.base_model.res4a_1_bn.running_mean→res4a_1_bn.running_mean
# module.base_model.res4a_1_bn.running_var→res4a_1_bn.running_var
# module.base_model.res4a_1_bn.num_batches_tracked→res4a_1_bn.num_batches_tracked
# module.base_model.res4a_2.weight→res4a_2.weight
# module.base_model.res4a_2.bias→res4a_2.bias
# module.base_model.res4a_down.weight→res4a_down.weight
# module.base_model.res4a_down.bias→res4a_down.bias
# module.base_model.res4a_bn.weight→res4a_bn.weight
# module.base_model.res4a_bn.bias→res4a_bn.bias
# module.base_model.res4a_bn.running_mean→res4a_bn.running_mean
# module.base_model.res4a_bn.running_var→res4a_bn.running_var
# module.base_model.res4a_bn.num_batches_tracked→res4a_bn.num_batches_tracked
# module.base_model.res4b_1.weight→res4b_1.weight
# module.base_model.res4b_1.bias→res4b_1.bias
# module.base_model.res4b_1_bn.weight→res4b_1_bn.weight
# module.base_model.res4b_1_bn.bias→res4b_1_bn.bias
# module.base_model.res4b_1_bn.running_mean→res4b_1_bn.running_mean
# module.base_model.res4b_1_bn.running_var→res4b_1_bn.running_var
# module.base_model.res4b_1_bn.num_batches_tracked→res4b_1_bn.num_batches_tracked
# module.base_model.res4b_2.weight→res4b_2.weight
# module.base_model.res4b_2.bias→res4b_2.bias
# module.base_model.res4b_bn.weight→res4b_bn.weight
# module.base_model.res4b_bn.bias→res4b_bn.bias
# module.base_model.res4b_bn.running_mean→res4b_bn.running_mean
# module.base_model.res4b_bn.running_var→res4b_bn.running_var
# module.base_model.res4b_bn.num_batches_tracked→res4b_bn.num_batches_tracked
# module.base_model.res5a_1.weight→res5a_1.weight
# module.base_model.res5a_1.bias→res5a_1.bias
# module.base_model.res5a_1_bn.weight→res5a_1_bn.weight
# module.base_model.res5a_1_bn.bias→res5a_1_bn.bias
# module.base_model.res5a_1_bn.running_mean→res5a_1_bn.running_mean
# module.base_model.res5a_1_bn.running_var→res5a_1_bn.running_var
# module.base_model.res5a_1_bn.num_batches_tracked→res5a_1_bn.num_batches_tracked
# module.base_model.res5a_2.weight→res5a_2.weight
# module.base_model.res5a_2.bias→res5a_2.bias
# module.base_model.res5a_down.weight→res5a_down.weight
# module.base_model.res5a_down.bias→res5a_down.bias
# module.base_model.res5a_bn.weight→res5a_bn.weight
# module.base_model.res5a_bn.bias→res5a_bn.bias
# module.base_model.res5a_bn.running_mean→res5a_bn.running_mean
# module.base_model.res5a_bn.running_var→res5a_bn.running_var
# module.base_model.res5a_bn.num_batches_tracked→res5a_bn.num_batches_tracked
# module.base_model.res5b_1.weight→res5b_1.weight
# module.base_model.res5b_1.bias→res5b_1.bias
# module.base_model.res5b_1_bn.weight→res5b_1_bn.weight
# module.base_model.res5b_1_bn.bias→res5b_1_bn.bias
# module.base_model.res5b_1_bn.running_mean→res5b_1_bn.running_mean
# module.base_model.res5b_1_bn.running_var→res5b_1_bn.running_var
# module.base_model.res5b_1_bn.num_batches_tracked→res5b_1_bn.num_batches_tracked
# module.base_model.res5b_2.weight→res5b_2.weight
# module.base_model.res5b_2.bias→res5b_2.bias
# module.base_model.res5b_bn.weight→res5b_bn.weight
# module.base_model.res5b_bn.bias→res5b_bn.bias
# module.base_model.res5b_bn.running_mean→res5b_bn.running_mean
# module.base_model.res5b_bn.running_var→res5b_bn.running_var
# module.base_model.res5b_bn.num_batches_tracked→res5b_bn.num_batches_tracked
# module.base_model.inception_3c_double_3x3_2.weight→inception_3c_double_3x3_2.weight
# module.base_model.inception_3c_double_3x3_2.bias→inception_3c_double_3x3_2.bias
# module.base_model.inception_3c_double_3x3_2_bn.weight→inception_3c_double_3x3_2_bn.weight
# module.base_model.inception_3c_double_3x3_2_bn.bias→inception_3c_double_3x3_2_bn.bias
# module.base_model.inception_3c_double_3x3_2_bn.running_mean→inception_3c_double_3x3_2_bn.running_mean
# module.base_model.inception_3c_double_3x3_2_bn.running_var→inception_3c_double_3x3_2_bn.running_var
# module.base_model.inception_3c_double_3x3_2_bn.num_batches_tracked→inception_3c_double_3x3_2_bn.num_batches_tracked
# module.base_model.inception_4a_1x1.weight→inception_4a_1x1.weight
# module.base_model.inception_4a_1x1.bias→inception_4a_1x1.bias
# module.base_model.inception_4a_1x1_bn.weight→inception_4a_1x1_bn.weight
# module.base_model.inception_4a_1x1_bn.bias→inception_4a_1x1_bn.bias
# module.base_model.inception_4a_1x1_bn.running_mean→inception_4a_1x1_bn.running_mean
# module.base_model.inception_4a_1x1_bn.running_var→inception_4a_1x1_bn.running_var
# module.base_model.inception_4a_1x1_bn.num_batches_tracked→inception_4a_1x1_bn.num_batches_tracked
# module.base_model.inception_4a_3x3_reduce.weight→inception_4a_3x3_reduce.weight
# module.base_model.inception_4a_3x3_reduce.bias→inception_4a_3x3_reduce.bias
# module.base_model.inception_4a_3x3_reduce_bn.weight→inception_4a_3x3_reduce_bn.weight
# module.base_model.inception_4a_3x3_reduce_bn.bias→inception_4a_3x3_reduce_bn.bias
# module.base_model.inception_4a_3x3_reduce_bn.running_mean→inception_4a_3x3_reduce_bn.running_mean
# module.base_model.inception_4a_3x3_reduce_bn.running_var→inception_4a_3x3_reduce_bn.running_var
# module.base_model.inception_4a_3x3_reduce_bn.num_batches_tracked→inception_4a_3x3_reduce_bn.num_batches_tracked
# module.base_model.inception_4a_3x3.weight→inception_4a_3x3.weight
# module.base_model.inception_4a_3x3.bias→inception_4a_3x3.bias
# module.base_model.inception_4a_3x3_bn.weight→inception_4a_3x3_bn.weight
# module.base_model.inception_4a_3x3_bn.bias→inception_4a_3x3_bn.bias
# module.base_model.inception_4a_3x3_bn.running_mean→inception_4a_3x3_bn.running_mean
# module.base_model.inception_4a_3x3_bn.running_var→inception_4a_3x3_bn.running_var
# module.base_model.inception_4a_3x3_bn.num_batches_tracked→inception_4a_3x3_bn.num_batches_tracked
# module.base_model.inception_4a_double_3x3_reduce.weight→inception_4a_double_3x3_reduce.weight
# module.base_model.inception_4a_double_3x3_reduce.bias→inception_4a_double_3x3_reduce.bias
# module.base_model.inception_4a_double_3x3_reduce_bn.weight→inception_4a_double_3x3_reduce_bn.weight
# module.base_model.inception_4a_double_3x3_reduce_bn.bias→inception_4a_double_3x3_reduce_bn.bias
# module.base_model.inception_4a_double_3x3_reduce_bn.running_mean→inception_4a_double_3x3_reduce_bn.running_mean
# module.base_model.inception_4a_double_3x3_reduce_bn.running_var→inception_4a_double_3x3_reduce_bn.running_var
# module.base_model.inception_4a_double_3x3_reduce_bn.num_batches_tracked→inception_4a_double_3x3_reduce_bn.num_batches_tracked
# module.base_model.inception_4a_double_3x3_1.weight→inception_4a_double_3x3_1.weight
# module.base_model.inception_4a_double_3x3_1.bias→inception_4a_double_3x3_1.bias
# module.base_model.inception_4a_double_3x3_1_bn.weight→inception_4a_double_3x3_1_bn.weight
# module.base_model.inception_4a_double_3x3_1_bn.bias→inception_4a_double_3x3_1_bn.bias
# module.base_model.inception_4a_double_3x3_1_bn.running_mean→inception_4a_double_3x3_1_bn.running_mean
# module.base_model.inception_4a_double_3x3_1_bn.running_var→inception_4a_double_3x3_1_bn.running_var
# module.base_model.inception_4a_double_3x3_1_bn.num_batches_tracked→inception_4a_double_3x3_1_bn.num_batches_tracked
# module.base_model.inception_4a_double_3x3_2.weight→inception_4a_double_3x3_2.weight
# module.base_model.inception_4a_double_3x3_2.bias→inception_4a_double_3x3_2.bias
# module.base_model.inception_4a_double_3x3_2_bn.weight→inception_4a_double_3x3_2_bn.weight
# module.base_model.inception_4a_double_3x3_2_bn.bias→inception_4a_double_3x3_2_bn.bias
# module.base_model.inception_4a_double_3x3_2_bn.running_mean→inception_4a_double_3x3_2_bn.running_mean
# module.base_model.inception_4a_double_3x3_2_bn.running_var→inception_4a_double_3x3_2_bn.running_var
# module.base_model.inception_4a_double_3x3_2_bn.num_batches_tracked→inception_4a_double_3x3_2_bn.num_batches_tracked
# module.base_model.inception_4a_pool_proj.weight→inception_4a_pool_proj.weight
# module.base_model.inception_4a_pool_proj.bias→inception_4a_pool_proj.bias
# module.base_model.inception_4a_pool_proj_bn.weight→inception_4a_pool_proj_bn.weight
# module.base_model.inception_4a_pool_proj_bn.bias→inception_4a_pool_proj_bn.bias
# module.base_model.inception_4a_pool_proj_bn.running_mean→inception_4a_pool_proj_bn.running_mean
# module.base_model.inception_4a_pool_proj_bn.running_var→inception_4a_pool_proj_bn.running_var
# module.base_model.inception_4a_pool_proj_bn.num_batches_tracked→inception_4a_pool_proj_bn.num_batches_tracked
# module.base_model.inception_4b_1x1.weight→inception_4b_1x1.weight
# module.base_model.inception_4b_1x1.bias→inception_4b_1x1.bias
# module.base_model.inception_4b_1x1_bn.weight→inception_4b_1x1_bn.weight
# module.base_model.inception_4b_1x1_bn.bias→inception_4b_1x1_bn.bias
# module.base_model.inception_4b_1x1_bn.running_mean→inception_4b_1x1_bn.running_mean
# module.base_model.inception_4b_1x1_bn.running_var→inception_4b_1x1_bn.running_var
# module.base_model.inception_4b_1x1_bn.num_batches_tracked→inception_4b_1x1_bn.num_batches_tracked
# module.base_model.inception_4b_3x3_reduce.weight→inception_4b_3x3_reduce.weight
# module.base_model.inception_4b_3x3_reduce.bias→inception_4b_3x3_reduce.bias
# module.base_model.inception_4b_3x3_reduce_bn.weight→inception_4b_3x3_reduce_bn.weight
# module.base_model.inception_4b_3x3_reduce_bn.bias→inception_4b_3x3_reduce_bn.bias
# module.base_model.inception_4b_3x3_reduce_bn.running_mean→inception_4b_3x3_reduce_bn.running_mean
# module.base_model.inception_4b_3x3_reduce_bn.running_var→inception_4b_3x3_reduce_bn.running_var
# module.base_model.inception_4b_3x3_reduce_bn.num_batches_tracked→inception_4b_3x3_reduce_bn.num_batches_tracked
# module.base_model.inception_4b_3x3.weight→inception_4b_3x3.weight
# module.base_model.inception_4b_3x3.bias→inception_4b_3x3.bias
# module.base_model.inception_4b_3x3_bn.weight→inception_4b_3x3_bn.weight
# module.base_model.inception_4b_3x3_bn.bias→inception_4b_3x3_bn.bias
# module.base_model.inception_4b_3x3_bn.running_mean→inception_4b_3x3_bn.running_mean
# module.base_model.inception_4b_3x3_bn.running_var→inception_4b_3x3_bn.running_var
# module.base_model.inception_4b_3x3_bn.num_batches_tracked→inception_4b_3x3_bn.num_batches_tracked
# module.base_model.inception_4b_double_3x3_reduce.weight→inception_4b_double_3x3_reduce.weight
# module.base_model.inception_4b_double_3x3_reduce.bias→inception_4b_double_3x3_reduce.bias
# module.base_model.inception_4b_double_3x3_reduce_bn.weight→inception_4b_double_3x3_reduce_bn.weight
# module.base_model.inception_4b_double_3x3_reduce_bn.bias→inception_4b_double_3x3_reduce_bn.bias
# module.base_model.inception_4b_double_3x3_reduce_bn.running_mean→inception_4b_double_3x3_reduce_bn.running_mean
# module.base_model.inception_4b_double_3x3_reduce_bn.running_var→inception_4b_double_3x3_reduce_bn.running_var
# module.base_model.inception_4b_double_3x3_reduce_bn.num_batches_tracked→inception_4b_double_3x3_reduce_bn.num_batches_tracked
# module.base_model.inception_4b_double_3x3_1.weight→inception_4b_double_3x3_1.weight
# module.base_model.inception_4b_double_3x3_1.bias→inception_4b_double_3x3_1.bias
# module.base_model.inception_4b_double_3x3_1_bn.weight→inception_4b_double_3x3_1_bn.weight
# module.base_model.inception_4b_double_3x3_1_bn.bias→inception_4b_double_3x3_1_bn.bias
# module.base_model.inception_4b_double_3x3_1_bn.running_mean→inception_4b_double_3x3_1_bn.running_mean
# module.base_model.inception_4b_double_3x3_1_bn.running_var→inception_4b_double_3x3_1_bn.running_var
# module.base_model.inception_4b_double_3x3_1_bn.num_batches_tracked→inception_4b_double_3x3_1_bn.num_batches_tracked
# module.base_model.inception_4b_double_3x3_2.weight→inception_4b_double_3x3_2.weight
# module.base_model.inception_4b_double_3x3_2.bias→inception_4b_double_3x3_2.bias
# module.base_model.inception_4b_double_3x3_2_bn.weight→inception_4b_double_3x3_2_bn.weight
# module.base_model.inception_4b_double_3x3_2_bn.bias→inception_4b_double_3x3_2_bn.bias
# module.base_model.inception_4b_double_3x3_2_bn.running_mean→inception_4b_double_3x3_2_bn.running_mean
# module.base_model.inception_4b_double_3x3_2_bn.running_var→inception_4b_double_3x3_2_bn.running_var
# module.base_model.inception_4b_double_3x3_2_bn.num_batches_tracked→inception_4b_double_3x3_2_bn.num_batches_tracked
# module.base_model.inception_4b_pool_proj.weight→inception_4b_pool_proj.weight
# module.base_model.inception_4b_pool_proj.bias→inception_4b_pool_proj.bias
# module.base_model.inception_4b_pool_proj_bn.weight→inception_4b_pool_proj_bn.weight
# module.base_model.inception_4b_pool_proj_bn.bias→inception_4b_pool_proj_bn.bias
# module.base_model.inception_4b_pool_proj_bn.running_mean→inception_4b_pool_proj_bn.running_mean
# module.base_model.inception_4b_pool_proj_bn.running_var→inception_4b_pool_proj_bn.running_var
# module.base_model.inception_4b_pool_proj_bn.num_batches_tracked→inception_4b_pool_proj_bn.num_batches_tracked
# module.base_model.inception_4c_1x1.weight→inception_4c_1x1.weight
# module.base_model.inception_4c_1x1.bias→inception_4c_1x1.bias
# module.base_model.inception_4c_1x1_bn.weight→inception_4c_1x1_bn.weight
# module.base_model.inception_4c_1x1_bn.bias→inception_4c_1x1_bn.bias
# module.base_model.inception_4c_1x1_bn.running_mean→inception_4c_1x1_bn.running_mean
# module.base_model.inception_4c_1x1_bn.running_var→inception_4c_1x1_bn.running_var
# module.base_model.inception_4c_1x1_bn.num_batches_tracked→inception_4c_1x1_bn.num_batches_tracked
# module.base_model.inception_4c_3x3_reduce.weight→inception_4c_3x3_reduce.weight
# module.base_model.inception_4c_3x3_reduce.bias→inception_4c_3x3_reduce.bias
# module.base_model.inception_4c_3x3_reduce_bn.weight→inception_4c_3x3_reduce_bn.weight
# module.base_model.inception_4c_3x3_reduce_bn.bias→inception_4c_3x3_reduce_bn.bias
# module.base_model.inception_4c_3x3_reduce_bn.running_mean→inception_4c_3x3_reduce_bn.running_mean
# module.base_model.inception_4c_3x3_reduce_bn.running_var→inception_4c_3x3_reduce_bn.running_var
# module.base_model.inception_4c_3x3_reduce_bn.num_batches_tracked→inception_4c_3x3_reduce_bn.num_batches_tracked
# module.base_model.inception_4c_3x3.weight→inception_4c_3x3.weight
# module.base_model.inception_4c_3x3.bias→inception_4c_3x3.bias
# module.base_model.inception_4c_3x3_bn.weight→inception_4c_3x3_bn.weight
# module.base_model.inception_4c_3x3_bn.bias→inception_4c_3x3_bn.bias
# module.base_model.inception_4c_3x3_bn.running_mean→inception_4c_3x3_bn.running_mean
# module.base_model.inception_4c_3x3_bn.running_var→inception_4c_3x3_bn.running_var
# module.base_model.inception_4c_3x3_bn.num_batches_tracked→inception_4c_3x3_bn.num_batches_tracked
# module.base_model.inception_4c_double_3x3_reduce.weight→inception_4c_double_3x3_reduce.weight
# module.base_model.inception_4c_double_3x3_reduce.bias→inception_4c_double_3x3_reduce.bias
# module.base_model.inception_4c_double_3x3_reduce_bn.weight→inception_4c_double_3x3_reduce_bn.weight
# module.base_model.inception_4c_double_3x3_reduce_bn.bias→inception_4c_double_3x3_reduce_bn.bias
# module.base_model.inception_4c_double_3x3_reduce_bn.running_mean→inception_4c_double_3x3_reduce_bn.running_mean
# module.base_model.inception_4c_double_3x3_reduce_bn.running_var→inception_4c_double_3x3_reduce_bn.running_var
# module.base_model.inception_4c_double_3x3_reduce_bn.num_batches_tracked→inception_4c_double_3x3_reduce_bn.num_batches_tracked
# module.base_model.inception_4c_double_3x3_1.weight→inception_4c_double_3x3_1.weight
# module.base_model.inception_4c_double_3x3_1.bias→inception_4c_double_3x3_1.bias
# module.base_model.inception_4c_double_3x3_1_bn.weight→inception_4c_double_3x3_1_bn.weight
# module.base_model.inception_4c_double_3x3_1_bn.bias→inception_4c_double_3x3_1_bn.bias
# module.base_model.inception_4c_double_3x3_1_bn.running_mean→inception_4c_double_3x3_1_bn.running_mean
# module.base_model.inception_4c_double_3x3_1_bn.running_var→inception_4c_double_3x3_1_bn.running_var
# module.base_model.inception_4c_double_3x3_1_bn.num_batches_tracked→inception_4c_double_3x3_1_bn.num_batches_tracked
# module.base_model.inception_4c_double_3x3_2.weight→inception_4c_double_3x3_2.weight
# module.base_model.inception_4c_double_3x3_2.bias→inception_4c_double_3x3_2.bias
# module.base_model.inception_4c_double_3x3_2_bn.weight→inception_4c_double_3x3_2_bn.weight
# module.base_model.inception_4c_double_3x3_2_bn.bias→inception_4c_double_3x3_2_bn.bias
# module.base_model.inception_4c_double_3x3_2_bn.running_mean→inception_4c_double_3x3_2_bn.running_mean
# module.base_model.inception_4c_double_3x3_2_bn.running_var→inception_4c_double_3x3_2_bn.running_var
# module.base_model.inception_4c_double_3x3_2_bn.num_batches_tracked→inception_4c_double_3x3_2_bn.num_batches_tracked
# module.base_model.inception_4c_pool_proj.weight→inception_4c_pool_proj.weight
# module.base_model.inception_4c_pool_proj.bias→inception_4c_pool_proj.bias
# module.base_model.inception_4c_pool_proj_bn.weight→inception_4c_pool_proj_bn.weight
# module.base_model.inception_4c_pool_proj_bn.bias→inception_4c_pool_proj_bn.bias
# module.base_model.inception_4c_pool_proj_bn.running_mean→inception_4c_pool_proj_bn.running_mean
# module.base_model.inception_4c_pool_proj_bn.running_var→inception_4c_pool_proj_bn.running_var
# module.base_model.inception_4c_pool_proj_bn.num_batches_tracked→inception_4c_pool_proj_bn.num_batches_tracked
# module.base_model.inception_4d_1x1.weight→inception_4d_1x1.weight
# module.base_model.inception_4d_1x1.bias→inception_4d_1x1.bias
# module.base_model.inception_4d_1x1_bn.weight→inception_4d_1x1_bn.weight
# module.base_model.inception_4d_1x1_bn.bias→inception_4d_1x1_bn.bias
# module.base_model.inception_4d_1x1_bn.running_mean→inception_4d_1x1_bn.running_mean
# module.base_model.inception_4d_1x1_bn.running_var→inception_4d_1x1_bn.running_var
# module.base_model.inception_4d_1x1_bn.num_batches_tracked→inception_4d_1x1_bn.num_batches_tracked
# module.base_model.inception_4d_3x3_reduce.weight→inception_4d_3x3_reduce.weight
# module.base_model.inception_4d_3x3_reduce.bias→inception_4d_3x3_reduce.bias
# module.base_model.inception_4d_3x3_reduce_bn.weight→inception_4d_3x3_reduce_bn.weight
# module.base_model.inception_4d_3x3_reduce_bn.bias→inception_4d_3x3_reduce_bn.bias
# module.base_model.inception_4d_3x3_reduce_bn.running_mean→inception_4d_3x3_reduce_bn.running_mean
# module.base_model.inception_4d_3x3_reduce_bn.running_var→inception_4d_3x3_reduce_bn.running_var
# module.base_model.inception_4d_3x3_reduce_bn.num_batches_tracked→inception_4d_3x3_reduce_bn.num_batches_tracked
# module.base_model.inception_4d_3x3.weight→inception_4d_3x3.weight
# module.base_model.inception_4d_3x3.bias→inception_4d_3x3.bias
# module.base_model.inception_4d_3x3_bn.weight→inception_4d_3x3_bn.weight
# module.base_model.inception_4d_3x3_bn.bias→inception_4d_3x3_bn.bias
# module.base_model.inception_4d_3x3_bn.running_mean→inception_4d_3x3_bn.running_mean
# module.base_model.inception_4d_3x3_bn.running_var→inception_4d_3x3_bn.running_var
# module.base_model.inception_4d_3x3_bn.num_batches_tracked→inception_4d_3x3_bn.num_batches_tracked
# module.base_model.inception_4d_double_3x3_reduce.weight→inception_4d_double_3x3_reduce.weight
# module.base_model.inception_4d_double_3x3_reduce.bias→inception_4d_double_3x3_reduce.bias
# module.base_model.inception_4d_double_3x3_reduce_bn.weight→inception_4d_double_3x3_reduce_bn.weight
# module.base_model.inception_4d_double_3x3_reduce_bn.bias→inception_4d_double_3x3_reduce_bn.bias
# module.base_model.inception_4d_double_3x3_reduce_bn.running_mean→inception_4d_double_3x3_reduce_bn.running_mean
# module.base_model.inception_4d_double_3x3_reduce_bn.running_var→inception_4d_double_3x3_reduce_bn.running_var
# module.base_model.inception_4d_double_3x3_reduce_bn.num_batches_tracked→inception_4d_double_3x3_reduce_bn.num_batches_tracked
# module.base_model.inception_4d_double_3x3_1.weight→inception_4d_double_3x3_1.weight
# module.base_model.inception_4d_double_3x3_1.bias→inception_4d_double_3x3_1.bias
# module.base_model.inception_4d_double_3x3_1_bn.weight→inception_4d_double_3x3_1_bn.weight
# module.base_model.inception_4d_double_3x3_1_bn.bias→inception_4d_double_3x3_1_bn.bias
# module.base_model.inception_4d_double_3x3_1_bn.running_mean→inception_4d_double_3x3_1_bn.running_mean
# module.base_model.inception_4d_double_3x3_1_bn.running_var→inception_4d_double_3x3_1_bn.running_var
# module.base_model.inception_4d_double_3x3_1_bn.num_batches_tracked→inception_4d_double_3x3_1_bn.num_batches_tracked
# module.base_model.inception_4d_double_3x3_2.weight→inception_4d_double_3x3_2.weight
# module.base_model.inception_4d_double_3x3_2.bias→inception_4d_double_3x3_2.bias
# module.base_model.inception_4d_double_3x3_2_bn.weight→inception_4d_double_3x3_2_bn.weight
# module.base_model.inception_4d_double_3x3_2_bn.bias→inception_4d_double_3x3_2_bn.bias
# module.base_model.inception_4d_double_3x3_2_bn.running_mean→inception_4d_double_3x3_2_bn.running_mean
# module.base_model.inception_4d_double_3x3_2_bn.running_var→inception_4d_double_3x3_2_bn.running_var
# module.base_model.inception_4d_double_3x3_2_bn.num_batches_tracked→inception_4d_double_3x3_2_bn.num_batches_tracked
# module.base_model.inception_4d_pool_proj.weight→inception_4d_pool_proj.weight
# module.base_model.inception_4d_pool_proj.bias→inception_4d_pool_proj.bias
# module.base_model.inception_4d_pool_proj_bn.weight→inception_4d_pool_proj_bn.weight
# module.base_model.inception_4d_pool_proj_bn.bias→inception_4d_pool_proj_bn.bias
# module.base_model.inception_4d_pool_proj_bn.running_mean→inception_4d_pool_proj_bn.running_mean
# module.base_model.inception_4d_pool_proj_bn.running_var→inception_4d_pool_proj_bn.running_var
# module.base_model.inception_4d_pool_proj_bn.num_batches_tracked→inception_4d_pool_proj_bn.num_batches_tracked
# module.base_model.inception_4e_3x3_reduce.weight→inception_4e_3x3_reduce.weight
# module.base_model.inception_4e_3x3_reduce.bias→inception_4e_3x3_reduce.bias
# module.base_model.inception_4e_3x3_reduce_bn.weight→inception_4e_3x3_reduce_bn.weight
# module.base_model.inception_4e_3x3_reduce_bn.bias→inception_4e_3x3_reduce_bn.bias
# module.base_model.inception_4e_3x3_reduce_bn.running_mean→inception_4e_3x3_reduce_bn.running_mean
# module.base_model.inception_4e_3x3_reduce_bn.running_var→inception_4e_3x3_reduce_bn.running_var
# module.base_model.inception_4e_3x3_reduce_bn.num_batches_tracked→inception_4e_3x3_reduce_bn.num_batches_tracked
# module.base_model.inception_4e_3x3.weight→inception_4e_3x3.weight
# module.base_model.inception_4e_3x3.bias→inception_4e_3x3.bias
# module.base_model.inception_4e_3x3_bn.weight→inception_4e_3x3_bn.weight
# module.base_model.inception_4e_3x3_bn.bias→inception_4e_3x3_bn.bias
# module.base_model.inception_4e_3x3_bn.running_mean→inception_4e_3x3_bn.running_mean
# module.base_model.inception_4e_3x3_bn.running_var→inception_4e_3x3_bn.running_var
# module.base_model.inception_4e_3x3_bn.num_batches_tracked→inception_4e_3x3_bn.num_batches_tracked
# module.base_model.inception_4e_double_3x3_reduce.weight→inception_4e_double_3x3_reduce.weight
# module.base_model.inception_4e_double_3x3_reduce.bias→inception_4e_double_3x3_reduce.bias
# module.base_model.inception_4e_double_3x3_reduce_bn.weight→inception_4e_double_3x3_reduce_bn.weight
# module.base_model.inception_4e_double_3x3_reduce_bn.bias→inception_4e_double_3x3_reduce_bn.bias
# module.base_model.inception_4e_double_3x3_reduce_bn.running_mean→inception_4e_double_3x3_reduce_bn.running_mean
# module.base_model.inception_4e_double_3x3_reduce_bn.running_var→inception_4e_double_3x3_reduce_bn.running_var
# module.base_model.inception_4e_double_3x3_reduce_bn.num_batches_tracked→inception_4e_double_3x3_reduce_bn.num_batches_tracked
# module.base_model.inception_4e_double_3x3_1.weight→inception_4e_double_3x3_1.weight
# module.base_model.inception_4e_double_3x3_1.bias→inception_4e_double_3x3_1.bias
# module.base_model.inception_4e_double_3x3_1_bn.weight→inception_4e_double_3x3_1_bn.weight
# module.base_model.inception_4e_double_3x3_1_bn.bias→inception_4e_double_3x3_1_bn.bias
# module.base_model.inception_4e_double_3x3_1_bn.running_mean→inception_4e_double_3x3_1_bn.running_mean
# module.base_model.inception_4e_double_3x3_1_bn.running_var→inception_4e_double_3x3_1_bn.running_var
# module.base_model.inception_4e_double_3x3_1_bn.num_batches_tracked→inception_4e_double_3x3_1_bn.num_batches_tracked
# module.base_model.inception_4e_double_3x3_2.weight→inception_4e_double_3x3_2.weight
# module.base_model.inception_4e_double_3x3_2.bias→inception_4e_double_3x3_2.bias
# module.base_model.inception_4e_double_3x3_2_bn.weight→inception_4e_double_3x3_2_bn.weight
# module.base_model.inception_4e_double_3x3_2_bn.bias→inception_4e_double_3x3_2_bn.bias
# module.base_model.inception_4e_double_3x3_2_bn.running_mean→inception_4e_double_3x3_2_bn.running_mean
# module.base_model.inception_4e_double_3x3_2_bn.running_var→inception_4e_double_3x3_2_bn.running_var
# module.base_model.inception_4e_double_3x3_2_bn.num_batches_tracked→inception_4e_double_3x3_2_bn.num_batches_tracked
# module.base_model.inception_5a_1x1.weight→inception_5a_1x1.weight
# module.base_model.inception_5a_1x1.bias→inception_5a_1x1.bias
# module.base_model.inception_5a_1x1_bn.weight→inception_5a_1x1_bn.weight
# module.base_model.inception_5a_1x1_bn.bias→inception_5a_1x1_bn.bias
# module.base_model.inception_5a_1x1_bn.running_mean→inception_5a_1x1_bn.running_mean
# module.base_model.inception_5a_1x1_bn.running_var→inception_5a_1x1_bn.running_var
# module.base_model.inception_5a_1x1_bn.num_batches_tracked→inception_5a_1x1_bn.num_batches_tracked
# module.base_model.inception_5a_3x3_reduce.weight→inception_5a_3x3_reduce.weight
# module.base_model.inception_5a_3x3_reduce.bias→inception_5a_3x3_reduce.bias
# module.base_model.inception_5a_3x3_reduce_bn.weight→inception_5a_3x3_reduce_bn.weight
# module.base_model.inception_5a_3x3_reduce_bn.bias→inception_5a_3x3_reduce_bn.bias
# module.base_model.inception_5a_3x3_reduce_bn.running_mean→inception_5a_3x3_reduce_bn.running_mean
# module.base_model.inception_5a_3x3_reduce_bn.running_var→inception_5a_3x3_reduce_bn.running_var
# module.base_model.inception_5a_3x3_reduce_bn.num_batches_tracked→inception_5a_3x3_reduce_bn.num_batches_tracked
# module.base_model.inception_5a_3x3.weight→inception_5a_3x3.weight
# module.base_model.inception_5a_3x3.bias→inception_5a_3x3.bias
# module.base_model.inception_5a_3x3_bn.weight→inception_5a_3x3_bn.weight
# module.base_model.inception_5a_3x3_bn.bias→inception_5a_3x3_bn.bias
# module.base_model.inception_5a_3x3_bn.running_mean→inception_5a_3x3_bn.running_mean
# module.base_model.inception_5a_3x3_bn.running_var→inception_5a_3x3_bn.running_var
# module.base_model.inception_5a_3x3_bn.num_batches_tracked→inception_5a_3x3_bn.num_batches_tracked
# module.base_model.inception_5a_double_3x3_reduce.weight→inception_5a_double_3x3_reduce.weight
# module.base_model.inception_5a_double_3x3_reduce.bias→inception_5a_double_3x3_reduce.bias
# module.base_model.inception_5a_double_3x3_reduce_bn.weight→inception_5a_double_3x3_reduce_bn.weight
# module.base_model.inception_5a_double_3x3_reduce_bn.bias→inception_5a_double_3x3_reduce_bn.bias
# module.base_model.inception_5a_double_3x3_reduce_bn.running_mean→inception_5a_double_3x3_reduce_bn.running_mean
# module.base_model.inception_5a_double_3x3_reduce_bn.running_var→inception_5a_double_3x3_reduce_bn.running_var
# module.base_model.inception_5a_double_3x3_reduce_bn.num_batches_tracked→inception_5a_double_3x3_reduce_bn.num_batches_tracked
# module.base_model.inception_5a_double_3x3_1.weight→inception_5a_double_3x3_1.weight
# module.base_model.inception_5a_double_3x3_1.bias→inception_5a_double_3x3_1.bias
# module.base_model.inception_5a_double_3x3_1_bn.weight→inception_5a_double_3x3_1_bn.weight
# module.base_model.inception_5a_double_3x3_1_bn.bias→inception_5a_double_3x3_1_bn.bias
# module.base_model.inception_5a_double_3x3_1_bn.running_mean→inception_5a_double_3x3_1_bn.running_mean
# module.base_model.inception_5a_double_3x3_1_bn.running_var→inception_5a_double_3x3_1_bn.running_var
# module.base_model.inception_5a_double_3x3_1_bn.num_batches_tracked→inception_5a_double_3x3_1_bn.num_batches_tracked
# module.base_model.inception_5a_double_3x3_2.weight→inception_5a_double_3x3_2.weight
# module.base_model.inception_5a_double_3x3_2.bias→inception_5a_double_3x3_2.bias
# module.base_model.inception_5a_double_3x3_2_bn.weight→inception_5a_double_3x3_2_bn.weight
# module.base_model.inception_5a_double_3x3_2_bn.bias→inception_5a_double_3x3_2_bn.bias
# module.base_model.inception_5a_double_3x3_2_bn.running_mean→inception_5a_double_3x3_2_bn.running_mean
# module.base_model.inception_5a_double_3x3_2_bn.running_var→inception_5a_double_3x3_2_bn.running_var
# module.base_model.inception_5a_double_3x3_2_bn.num_batches_tracked→inception_5a_double_3x3_2_bn.num_batches_tracked
# module.base_model.inception_5a_pool_proj.weight→inception_5a_pool_proj.weight
# module.base_model.inception_5a_pool_proj.bias→inception_5a_pool_proj.bias
# module.base_model.inception_5a_pool_proj_bn.weight→inception_5a_pool_proj_bn.weight
# module.base_model.inception_5a_pool_proj_bn.bias→inception_5a_pool_proj_bn.bias
# module.base_model.inception_5a_pool_proj_bn.running_mean→inception_5a_pool_proj_bn.running_mean
# module.base_model.inception_5a_pool_proj_bn.running_var→inception_5a_pool_proj_bn.running_var
# module.base_model.inception_5a_pool_proj_bn.num_batches_tracked→inception_5a_pool_proj_bn.num_batches_tracked
# module.base_model.inception_5b_1x1.weight→inception_5b_1x1.weight
# module.base_model.inception_5b_1x1.bias→inception_5b_1x1.bias
# module.base_model.inception_5b_1x1_bn.weight→inception_5b_1x1_bn.weight
# module.base_model.inception_5b_1x1_bn.bias→inception_5b_1x1_bn.bias
# module.base_model.inception_5b_1x1_bn.running_mean→inception_5b_1x1_bn.running_mean
# module.base_model.inception_5b_1x1_bn.running_var→inception_5b_1x1_bn.running_var
# module.base_model.inception_5b_1x1_bn.num_batches_tracked→inception_5b_1x1_bn.num_batches_tracked
# module.base_model.inception_5b_3x3_reduce.weight→inception_5b_3x3_reduce.weight
# module.base_model.inception_5b_3x3_reduce.bias→inception_5b_3x3_reduce.bias
# module.base_model.inception_5b_3x3_reduce_bn.weight→inception_5b_3x3_reduce_bn.weight
# module.base_model.inception_5b_3x3_reduce_bn.bias→inception_5b_3x3_reduce_bn.bias
# module.base_model.inception_5b_3x3_reduce_bn.running_mean→inception_5b_3x3_reduce_bn.running_mean
# module.base_model.inception_5b_3x3_reduce_bn.running_var→inception_5b_3x3_reduce_bn.running_var
# module.base_model.inception_5b_3x3_reduce_bn.num_batches_tracked→inception_5b_3x3_reduce_bn.num_batches_tracked
# module.base_model.inception_5b_3x3.weight→inception_5b_3x3.weight
# module.base_model.inception_5b_3x3.bias→inception_5b_3x3.bias
# module.base_model.inception_5b_3x3_bn.weight→inception_5b_3x3_bn.weight
# module.base_model.inception_5b_3x3_bn.bias→inception_5b_3x3_bn.bias
# module.base_model.inception_5b_3x3_bn.running_mean→inception_5b_3x3_bn.running_mean
# module.base_model.inception_5b_3x3_bn.running_var→inception_5b_3x3_bn.running_var
# module.base_model.inception_5b_3x3_bn.num_batches_tracked→inception_5b_3x3_bn.num_batches_tracked
# module.base_model.inception_5b_double_3x3_reduce.weight→inception_5b_double_3x3_reduce.weight
# module.base_model.inception_5b_double_3x3_reduce.bias→inception_5b_double_3x3_reduce.bias
# module.base_model.inception_5b_double_3x3_reduce_bn.weight→inception_5b_double_3x3_reduce_bn.weight
# module.base_model.inception_5b_double_3x3_reduce_bn.bias→inception_5b_double_3x3_reduce_bn.bias
# module.base_model.inception_5b_double_3x3_reduce_bn.running_mean→inception_5b_double_3x3_reduce_bn.running_mean
# module.base_model.inception_5b_double_3x3_reduce_bn.running_var→inception_5b_double_3x3_reduce_bn.running_var
# module.base_model.inception_5b_double_3x3_reduce_bn.num_batches_tracked→inception_5b_double_3x3_reduce_bn.num_batches_tracked
# module.base_model.inception_5b_double_3x3_1.weight→inception_5b_double_3x3_1.weight
# module.base_model.inception_5b_double_3x3_1.bias→inception_5b_double_3x3_1.bias
# module.base_model.inception_5b_double_3x3_1_bn.weight→inception_5b_double_3x3_1_bn.weight
# module.base_model.inception_5b_double_3x3_1_bn.bias→inception_5b_double_3x3_1_bn.bias
# module.base_model.inception_5b_double_3x3_1_bn.running_mean→inception_5b_double_3x3_1_bn.running_mean
# module.base_model.inception_5b_double_3x3_1_bn.running_var→inception_5b_double_3x3_1_bn.running_var
# module.base_model.inception_5b_double_3x3_1_bn.num_batches_tracked→inception_5b_double_3x3_1_bn.num_batches_tracked
# module.base_model.inception_5b_double_3x3_2.weight→inception_5b_double_3x3_2.weight
# module.base_model.inception_5b_double_3x3_2.bias→inception_5b_double_3x3_2.bias
# module.base_model.inception_5b_double_3x3_2_bn.weight→inception_5b_double_3x3_2_bn.weight
# module.base_model.inception_5b_double_3x3_2_bn.bias→inception_5b_double_3x3_2_bn.bias
# module.base_model.inception_5b_double_3x3_2_bn.running_mean→inception_5b_double_3x3_2_bn.running_mean
# module.base_model.inception_5b_double_3x3_2_bn.running_var→inception_5b_double_3x3_2_bn.running_var
# module.base_model.inception_5b_double_3x3_2_bn.num_batches_tracked→inception_5b_double_3x3_2_bn.num_batches_tracked
# module.base_model.inception_5b_pool_proj.weight→inception_5b_pool_proj.weight
# module.base_model.inception_5b_pool_proj.bias→inception_5b_pool_proj.bias
# module.base_model.inception_5b_pool_proj_bn.weight→inception_5b_pool_proj_bn.weight
# module.base_model.inception_5b_pool_proj_bn.bias→inception_5b_pool_proj_bn.bias
# module.base_model.inception_5b_pool_proj_bn.running_mean→inception_5b_pool_proj_bn.running_mean
# module.base_model.inception_5b_pool_proj_bn.running_var→inception_5b_pool_proj_bn.running_var
# module.base_model.inception_5b_pool_proj_bn.num_batches_tracked→inception_5b_pool_proj_bn.num_batches_tracked
# module.base_model.fc_final.weight→fc_final.weight
# module.base_model.fc_final.bias→fc_final.bias

# %%
net.eval()  

batch_iterator = iter(val_dataloader)  
imgs_transformeds, labels, label_ids, dir_path = next(
    batch_iterator)  

with torch.set_grad_enabled(False):
    outputs = net(imgs_transformeds)  

print(outputs.shape)
# Out:
# ('inception_3c_relu_double_3x3_1_out:', torch.Size([128, 96, 28, 28]))
# torch.Size([8, 16, 96, 28, 28])
# torch.Size([8, 96, 16, 28, 28])
# ('fc_final_out:', torch.Size([8, 400]))
# torch.Size([8, 400])

# %% [markdown]
# # Classification of video data

# %%
dir_path
# Out:
# ('./data/kinetics_videos/bungee jumping/zkXOcxGnUhs_000025_000035',
#  './data/kinetics_videos/bungee jumping/dAeUFSdYG1I_000010_000020',
#  './data/kinetics_videos/bungee jumping/TUvSX0pYu4o_000002_000012',
#  './data/kinetics_videos/bungee jumping/b6yQZjPE26c_000023_000033',
#  './data/kinetics_videos/arm wrestling/BdMiTo_OtnU_000024_000034',
#  './data/kinetics_videos/arm wrestling/5JzkrOVhPOw_000027_000037',
#  './data/kinetics_videos/arm wrestling/ehLnj7pXnYE_000027_000037',
#  './data/kinetics_videos/arm wrestling/C4lCVBZ3ux0_000028_000038')

# %%
def show_eco_inference_result(dir_path, outputs_input, id_label_dict, idx):
    print("File：", dir_path[idx])  
    
    outputs = outputs_input.clone()  
    
    
    for i in range(5):
      
        output = outputs[idx]
        
        _, pred = torch.max(output, dim=0) 
        
        class_idx = int(pred.numpy())
        
        print("Forcast{}：{}".format(i+1, id_label_dict[class_idx]))
        outputs[idx][class_idx] = -1000

# %% [markdown]
# ### Top 5 Predictions

# %%
idx = 0
show_eco_inference_result(dir_path, outputs, id_label_dict, idx)
# Out:
# ('File\xef\xbc\x9a', './data/kinetics_videos/bungee jumping/zkXOcxGnUhs_000025_000035')
# Forcast1：bungee jumping
# Forcast2：diving cliff
# Forcast3：swinging on something
# Forcast4：skydiving
# Forcast5：abseiling

# %%
idx = 5
show_eco_inference_result(dir_path, outputs, id_label_dict, idx)
# Out:
# ('File\xef\xbc\x9a', './data/kinetics_videos/arm wrestling/5JzkrOVhPOw_000027_000037')
# Forcast1：arm wrestling
# Forcast2：headbutting
# Forcast3：rock scissors paper
# Forcast4：sniffing
# Forcast5：shaking hands

# %%
idx = 7
show_eco_inference_result(dir_path, outputs, id_label_dict, idx)
# Out:
# ('File\xef\xbc\x9a', './data/kinetics_videos/arm wrestling/C4lCVBZ3ux0_000028_000038')
# Forcast1：arm wrestling
# Forcast2：shaking hands
# Forcast3：rock scissors paper
# Forcast4：tai chi
# Forcast5：cutting nails

# %%
idx = 2
show_eco_inference_result(dir_path, outputs, id_label_dict, idx)
# Out:
# ('File\xef\xbc\x9a', './data/kinetics_videos/bungee jumping/TUvSX0pYu4o_000002_000012')
# Forcast1：bungee jumping
# Forcast2：abseiling
# Forcast3：swinging on something
# Forcast4：trapezing
# Forcast5：climbing ladder

# %% [markdown]
# ### Top 10 predictions:

# %%
def show_eco_inference_result_10(dir_path, outputs_input, id_label_dict, idx):
    print("File：", dir_path[idx])  
    
    outputs = outputs_input.clone()  
    
    
    for i in range(10):
      
        output = outputs[idx]
        
        _, pred = torch.max(output, dim=0) 
        
        class_idx = int(pred.numpy())
        
        print("Forcast{}：{}".format(i+1, id_label_dict[class_idx]))
        outputs[idx][class_idx] = -1000

# %%
idx = 2
show_eco_inference_result_10(dir_path, outputs, id_label_dict, idx)
# Out:
# ('File\xef\xbc\x9a', './data/kinetics_videos/bungee jumping/TUvSX0pYu4o_000002_000012')
# Forcast1：bungee jumping
# Forcast2：abseiling
# Forcast3：swinging on something
# Forcast4：trapezing
# Forcast5：climbing ladder
# Forcast6：rock climbing
# Forcast7：parasailing
# Forcast8：bouncing on trampoline
# Forcast9：somersaulting
# Forcast10：exercising with an exercise ball
